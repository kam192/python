# %%
import numpy as np
from scipy.io import wavfile
import os
import time
import h5py
import traceback
import IPython.display as ipd
import matplotlib.pyplot as plt
from glob import glob
import librosa as lr

# %%
import librosa
from librosa import display
dataset_dir = os.getcwd() + "\\SER"
audio_files=glob(dataset_dir + '/*.wav')
print(audio_files)
# Out:
# ['D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-01.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-03.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-05.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-07.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-09.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-11.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-13.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-15.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-17.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-19.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-21.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-01-23.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-02-01.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-02-03.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-02-05.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-02-07.wav', 'D:\\jupyter\\TermPaper\\SER\\03-01-01-01-01-02-09.wav', 'D:\\jupyter\\TermPaper\\SER
# ...

# %%
audio,sfreq=lr.load(audio_files[0])
time = np.arange(0,len(audio_files))/ sfreq

# %%
dataset_dir = os.getcwd() + "\\SER"
audio_files=glob(dataset_dir + '/*.wav')
print(dataset_dir)
len(audio_files)
# Out:
# D:\jupyter\TermPaper\SER
# 1247

# %%
audio,sfreq=lr.load(audio_files[0])
time = np.arange(0,len(audio_files))/ sfreq

# %%
fig, ax=plt.subplots()
ax.plot(time,audio_files)
ax.set(xlabel='Time(s)', ylabel='Sound Amplitude')
plt.show()
