# %%
#BASICS OF PANDAS
#It sotres dat in key value pair

# %%
import numpy as np
import pandas as pd

# %%
#working with dictionaries in Python
myDict = {'Name':'Kamran', 'ID': 1403001 , 'Class': 'MSCS'}

# %%
myDict['Class']
# Out:
# 'MSCS'

# %%
df=pd.read_csv("sms.csv", skiprows=1)
#can give the name to columns ai ti does not exist 
#df=pd.read_csv("sms.csv", header=None, names=["Message", 'batain'])
#if number of rows are too many we can reead specific number of rows by using
#df=pd.read_csv("sms.csv", nrows=50)
#in order tofill milling values see code below
df=pd.read_csv("sms.csv", na_values=["not available",'n.a.'])

# %%
df
# Out:
#       App see Sadaf mob pe txt jaty Hain sb ko pta ha na tb sb janty Hain or ma ne bola k larkiun ka Kya ha ATI jati Hain ma larkiun k lye nai kamata ye Mera time pas ha  18/06/18 02:17:22 AM
# 0      ap sehan ma ao na g hot bhe ho jaty han or sex...
# 1      Or sano kasi ho mera jann yr ni la k ata ok ap...
# 2      Hn jon sa cht pr lika ta \r\n1st tme\r\nWo wal...
# 3      Han g grmio sardio me ap jate thy tijarat krne...
# 4      phly ap mujai btao phr ma kis kro ga apni jan ...
# 5      Ok thik hy tm ne kuch b ni kaha me e bkwas krt...
# 6      acha g ma kbi nhi lri kro ga bs tm muj se puch...
# 7        Wo konsa gna tha noor wala 18/06/18 02:18:01 AM
# 8      Koye pta ni ghanta dar lag jaey ga 18/06/18 02...
# 9      \r\nApni bebasi par aaj fir mujhe rona sa aaya...
# 10     It's ok....soo jao good night  18/06/18 02:18:...
# 11     To mene pocha ni k kis bat ka dar hy tmhn 18/0...
# 12        Jab free hoi jan txt krna 18/06/18 02:18:35 AM
# ...

# %%
#To write data in a CSV
df.to_csv('new.csv')
